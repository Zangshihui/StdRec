# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
den1 = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Density/fiducial/0/Den_DMStdIter_10_3.bin', dtype = np.float32).reshape([512, 512, 512])
plt.imshow(den1[:, :, 255], vmin = 0, vmax = 3)

# %%
Kf = 2*np.pi/1000
k = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/k.bin', dtype = np.float32)*Kf
Pk_IC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_IC.bin', dtype = np.float32)
Pk_DMStdRec = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_DMStdRec.bin', dtype = np.float32)
Pc_DMStdRecIC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pc_DMStdRecIC.bin', dtype = np.float32)
rk = Pc_DMStdRecIC/(Pk_IC*Pk_DMStdRec)**0.5
plt.semilogx(k, rk)

Pk_IC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_IC.bin', dtype = np.float32)
Pk_DMStdRec = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_DMRec.bin', dtype = np.float32)
Pc_DMStdRecIC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pc_DMRec.bin', dtype = np.float32)
rk = Pc_DMStdRecIC/(Pk_IC*Pk_DMStdRec)**0.5
plt.semilogx(k, rk)

Pk_IC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_IC.bin', dtype = np.float32)
Pk_DMStdRec = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk.bin', dtype = np.float32)
Pc_DMStdRecIC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pc.bin', dtype = np.float32)
rk = Pc_DMStdRecIC/(Pk_IC*Pk_DMStdRec)**0.5
plt.semilogx(k, rk)

# %%
NUMS = 100
Para = 'fiducial'

Kf = 2*np.pi/1000
k = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/k.bin', dtype = np.float32)*Kf

Pk = np.ones([NUMS, 256])
for i in range(NUMS):
    PkPATH = '/scratch/p/pen/zangsh/Quijote_Simulations/Power/' + Para + '/' + str(i) + '/Pc_Halo_1.0.bin'
    Pk[i, :256] = np.fromfile(PkPATH, dtype = np.float32)
#     plt.loglog(k, Pk[i, :] )
Phm_ave = Pk.mean(axis = 0)

Pk = np.ones([NUMS, 256])
for i in range(NUMS):
    PkPATH = '/scratch/p/pen/zangsh/Quijote_Simulations/Power/' + Para + '/' + str(i) + '/Pk_1.0.bin'
    Pk[i, :256] = np.fromfile(PkPATH, dtype = np.float32)
Pmm_ave = Pk.mean(axis = 0)

plt.loglog(k, Phm_ave/Pmm_ave)

# %%
Kf = 2*np.pi/1000
k = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/k.bin', dtype = np.float32)*Kf
Pk_IC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_IC.bin', dtype = np.float32)
Pk_DMStdRec = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_Halo.bin', dtype = np.float32)
Pc_DMStdRecIC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pc_HaloIC.bin', dtype = np.float32)
rk = Pc_DMStdRecIC/(Pk_IC*Pk_DMStdRec)**0.5
plt.semilogx(k, rk, c = 'k', lw = 0.8, label = '$Halo$')

Kf = 2*np.pi/1000
k = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/k.bin', dtype = np.float32)*Kf
Pk_IC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_IC.bin', dtype = np.float32)
Pk_DMStdRec = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_HaloBRec.bin', dtype = np.float32)
Pc_DMStdRecIC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pc_HaloBRecIC.bin', dtype = np.float32)
rk = Pc_DMStdRecIC/(Pk_IC*Pk_DMStdRec)**0.5
plt.semilogx(k, rk, c = 'g', lw = 0.8, ls = '-', label = 'BaojiuRec')

Pk_IC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_IC.bin', dtype = np.float32)
Pk_DMStdRec = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_HaloStdRec.bin', dtype = np.float32)
Pc_DMStdRecIC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pc_HaloStdRecIC.bin', dtype = np.float32)
rk = Pc_DMStdRecIC/(Pk_IC*Pk_DMStdRec)**0.5
plt.semilogx(k, rk, c = 'r', lw = 0.8, ls = '-', label = 'StdRec')

Pk_IC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_IC.bin', dtype = np.float32)
Pk_DMStdRec = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_HaloStdIter_10_3.bin', dtype = np.float32)
Pc_DMStdRecIC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pc_HaloStdIter_10_3.bin', dtype = np.float32)
rk = Pc_DMStdRecIC/(Pk_IC*Pk_DMStdRec)**0.5
plt.semilogx(k, rk, c = 'r', lw = 0.8, ls = '--', label = 'StdIter')
plt.xlabel(r'$k$ $[h \mathrm{Mpc}^{-1}]$', fontsize = 12, verticalalignment='top')
plt.ylabel(r'$P(k)$', fontsize = 12, verticalalignment='bottom')
plt.legend()
plt.savefig('/home/p/pen/zangsh/pics/StdBRec.pdf', bbox_inches='tight')

# %%
cmp = plt.cm.ocean
Kf = 2*np.pi/1000
k = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/k.bin', dtype = np.float32)*Kf
Pk_IC = np.zeros([256, 1])
for I in range(1):
    Pk_IC[:, I] = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/' + str(I) + '/Pk_IC.bin', dtype = np.float32)
Pk_IC_ave = Pk_IC.mean(axis = 1)
Pk = np.zeros([256, 1])
Pc = np.zeros([256, 1])

for I in range(1):
    Pk[:, I] = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/' + str(I) + '/Pk_HaloStdRec_z0.0_R5.bin', dtype = np.float32)
    Pc[:, I] = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/' + str(I) + '/Pc_HaloStdRec_z0.0_R5.bin', dtype = np.float32)
Pk_ave = Pk.mean(axis = 1)
Pc_ave = Pc.mean(axis = 1)
rk = Pc_ave/(Pk_ave*Pk_IC_ave)**0.5
plt.semilogx(k, rk, label = 'StdRec $R = 5$', lw = 1, c = 'r')

Kf = 2*np.pi/1000
k = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/k.bin', dtype = np.float32)*Kf
Pk_IC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_IC.bin', dtype = np.float32)
Pk_DMStdRec = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_HaloBRec.bin', dtype = np.float32)
Pc_DMStdRecIC = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pc_HaloBRecIC.bin', dtype = np.float32)
rk = Pc_DMStdRecIC/(Pk_IC*Pk_DMStdRec)**0.5
plt.semilogx(k, rk, c = 'g', lw = 0.8, ls = '-', label = 'BRec')
plt.legend()

plt.xlabel(r'$k$ $[h \mathrm{Mpc}^{-1}]$', fontsize = 12, verticalalignment='top')
plt.ylabel(r'$r(k)$', fontsize = 12, verticalalignment='bottom')
plt.legend()
plt.savefig('/home/p/pen/zangsh/pics/StdBRec.pdf', bbox_inches='tight')

# %%
Omega_m = 0.3175
Omega_Lambda = 1 - Omega_m
H0 = 67.11
z = 0.5
H = H0*(Omega_m*(1 + z)**3 + Omega_Lambda)**0.5
print('H is ', H)
# Out:
# H is  88.88117161641294

# %%
cmap=plt.cm.Greens
k = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/k_2DBin.bin', dtype = np.float32).reshape([256, 5])*Kf
Pk1 = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_2DBin_IC.bin', dtype = np.float32).reshape([256, 5])
Pk2 = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_2DBin_HaloBRec_z0.0_RS2.bin', dtype = np.float32).reshape([256, 5])
Pc = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pc_2DBin_ICHaloBRec_z0.0_RS2.bin', dtype = np.float32).reshape([256, 5])
rk = Pc/(Pk1*Pk2)**0.5
for I in range(5):
    if I ==4:
        plt.semilogx(k[:, I], rk[:, I], c = cmap(I*0.2), label = 'BRec')
    else:
        plt.semilogx(k[:, I], rk[:, I], c = cmap(I*0.2))

cmap=plt.cm.Reds
k = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/k_2DBin.bin', dtype = np.float32).reshape([256, 5])*Kf
Pk1 = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_2DBin_IC.bin', dtype = np.float32).reshape([256, 5])
Pk2 = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_2DBin_HaloStdRec_z0.0_RS2_R5.bin', dtype = np.float32).reshape([256, 5])
Pc = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pc_2DBin_ICHaloStdRec_z0.0_RS2_R5.bin', dtype = np.float32).reshape([256, 5])
rk = Pc/(Pk1*Pk2)**0.5
for I in range(5):
    if I == 4 :                
        plt.semilogx(k[:, I], rk[:, I], c = cmap(I*0.2), label = 'StdRec')
    else:
        plt.semilogx(k[:, I], rk[:, I], c = cmap(I*0.2))

plt.xlabel(r'$k$ $[h \mathrm{Mpc}^{-1}]$', fontsize = 12, verticalalignment='top')
plt.ylabel(r'$r(k)$', fontsize = 12, verticalalignment='bottom')
plt.legend()
plt.text(0.01, 0, 'RS2, z = 0.0', fontsize = 15)
plt.savefig('/home/p/pen/zangsh/pics/StdBRec_z0.0_RS2.pdf', bbox_inches='tight')

# %%
cmap=plt.cm.Greens
k = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/k_2DBin.bin', dtype = np.float32).reshape([256, 5])*Kf
Pk1 = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_2DBin_IC.bin', dtype = np.float32).reshape([256, 5])
Pk2 = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_2DBin_HaloBRec_z0.5_RS2.bin', dtype = np.float32).reshape([256, 5])
Pc = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pc_2DBin_ICHaloBRec_z0.5_RS2.bin', dtype = np.float32).reshape([256, 5])
rk = Pc/(Pk1*Pk2)**0.5
for I in range(5):
    if I ==4:
        plt.semilogx(k[:, I], rk[:, I], c = cmap(I*0.2), label = 'BRec')
    else:
        plt.semilogx(k[:, I], rk[:, I], c = cmap(I*0.2))

cmap=plt.cm.Reds
k = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/k_2DBin.bin', dtype = np.float32).reshape([256, 5])*Kf
Pk1 = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_2DBin_IC.bin', dtype = np.float32).reshape([256, 5])
Pk2 = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_2DBin_HaloStdRec_z0.5_RS2_R5.bin', dtype = np.float32).reshape([256, 5])
Pc = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pc_2DBin_ICHaloStdRec_z0.5_RS2_R5.bin', dtype = np.float32).reshape([256, 5])
rk = Pc/(Pk1*Pk2)**0.5
for I in range(5):
    if I == 4 :                
        plt.semilogx(k[:, I], rk[:, I], c = cmap(I*0.2), label = 'StdRec')
    else:
        plt.semilogx(k[:, I], rk[:, I], c = cmap(I*0.2))

plt.xlabel(r'$k$ $[h \mathrm{Mpc}^{-1}]$', fontsize = 12, verticalalignment='top')
plt.ylabel(r'$r(k)$', fontsize = 12, verticalalignment='bottom')
plt.legend()
plt.text(0.01, 0, 'RS2, z = 0.0', fontsize = 15)
plt.savefig('/home/p/pen/zangsh/pics/StdBRec_z0.5_RS2.pdf', bbox_inches='tight')

# %%
cmap=plt.cm.Reds
k = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/k_2DBin.bin', dtype = np.float32).reshape([256, 5])*Kf
Pk1 = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_2DBin_IC.bin', dtype = np.float32).reshape([256, 5])
Pk2 = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_2DBin_HaloStdRec_z0.0_RS2_R5.bin', dtype = np.float32).reshape([256, 5])
Pc = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pc_2DBin_ICHaloStdRec_z0.0_RS2_R5.bin', dtype = np.float32).reshape([256, 5])
rk = Pc/(Pk1*Pk2)**0.5
for I in range(5):
    if I == 4 :                
        plt.semilogx(k[:, I], rk[:, I], c = cmap(I*0.2), label = 'StdIter1')
    else:
        plt.semilogx(k[:, I], rk[:, I], c = cmap(I*0.2))
        
cmap=plt.cm.RdPu
k = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/k_2DBin.bin', dtype = np.float32).reshape([256, 5])*Kf
Pk1 = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_2DBin_IC.bin', dtype = np.float32).reshape([256, 5])
Pk2 = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_2DBin_HaloStdIter_z0.0_RS2_R5_2.bin', dtype = np.float32).reshape([256, 5])
Pc = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pc_2DBin_ICHaloStdIter_z0.0_RS2_R5_2.bin', dtype = np.float32).reshape([256, 5])
rk = Pc/(Pk1*Pk2)**0.5
for I in range(5):
    if I == 4 :                
        plt.semilogx(k[:, I], rk[:, I], c = cmap(I*0.2), label = 'StdIter2')
    else:
        plt.semilogx(k[:, I], rk[:, I], c = cmap(I*0.2))
        
cmap=plt.cm.BuPu
k = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/k_2DBin.bin', dtype = np.float32).reshape([256, 5])*Kf
Pk1 = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_2DBin_IC.bin', dtype = np.float32).reshape([256, 5])
Pk2 = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pk_2DBin_HaloStdIter_z0.0_RS2_R5_3.bin', dtype = np.float32).reshape([256, 5])
Pc = np.fromfile('/scratch/p/pen/zangsh/Quijote_Simulations/Power/fiducial/0/Pc_2DBin_ICHaloStdIter_z0.0_RS2_R5_3.bin', dtype = np.float32).reshape([256, 5])
rk = Pc/(Pk1*Pk2)**0.5
for I in range(5):
    if I == 4 :                
        plt.semilogx(k[:, I], rk[:, I], c = cmap(I*0.2), label = 'StdIter3')
    else:
        plt.semilogx(k[:, I], rk[:, I], c = cmap(I*0.2))
        
plt.xlabel(r'$k$ $[h \mathrm{Mpc}^{-1}]$', fontsize = 12, verticalalignment='top')
plt.ylabel(r'$r(k)$', fontsize = 12, verticalalignment='bottom')
plt.legend()
plt.text(0.01, 0, 'RS2, z = 0.0', fontsize = 15)
plt.savefig('/home/p/pen/zangsh/pics/StdIter_z0.0_RS2.pdf', bbox_inches='tight')
